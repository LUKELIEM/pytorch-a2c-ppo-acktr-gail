# %%
import numpy as np
import csv
from baselines.common import plot_util as pu
from baselines.common.plot_util import smooth

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# If you want to average results for multiple seeds, LOG_DIRS must contain subfolders in the following format: ```<name_exp0>-0```, ```<name_exp0>-1```, ```<name_exp1>-0```, ```<name_exp1>-1```. Where names correspond to experiments you want to compare separated with random seeds by dash.

# %%
LOG_DIRS = 'logs/pong_ppo/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [    817    1635    2455 ... 9991565 9993678 9996079] [-20.18181818 -20.25       -20.30769231 ...  20.07692308  20.
#   20.        ]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/pong_a2c/'
results = pu.load_results(LOG_DIRS, verbose=True)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# skipping logs/pong_a2c/: no progress file
# successfully loaded logs/pong_a2c/
# loaded 1 results
# [    757    1514    2272 ... 9990037 9991783 9993433] [-21.         -21.         -21.         ...  19.92307692  20.
#   20.09090909]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/breakout_ppo/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility
# [     127      254      381 ... 10091504 10093806 10095831] [  1.54545455   1.41666667   1.46153846 ... 403.46153846 402.41666667
#  400.72727273]

# %%
LOG_DIRS = 'logs/breakout_a2c/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility
# [     125      252      379 ... 10083128 10086103 10088683] [  0.45454545   0.58333333   0.53846154 ... 318.61538462 314.66666667
#  312.09090909]

# %%
LOG_DIRS = 'logs/centepede_ppo/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [     456      947     1453 ... 10123759 10124347 10124905] [2446.72727273 2461.66666667 2436.15384615 ... 2461.61538462 2456.58333333
#  2498.63636364]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/centepede_a2c/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [     481      976     1526 ... 10149052 10149302 10149750] [2239.63636364 2477.83333333 2578.53846154 ... 3351.92307692 3349.75
#  3372.63636364]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/robotank_ppo/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [    1326     2882     4631 ... 10017763 10021039 10024445] [1.09090909 1.16666667 1.07692308 ... 7.92307692 7.58333333 8.        ]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/robotank_a2c/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [    1039     2553     4165 ... 10023567 10026646 10028153] [1.36363636 1.33333333 1.30769231 ... 2.         1.91666667 2.        ]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/alien_ppo/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [     497     1051     1645 ... 10100101 10101198 10102409] [ 180.          180.          180.         ... 1478.46153846 1476.66666667
#  1469.09090909]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
LOG_DIRS = 'logs/alien_a2c/'
results = pu.load_results(LOG_DIRS)
fig = pu.plot_results(results, average_group=True, split_fn=lambda _: '', shaded_std=False)
# Out:
# [     371      745     1125 ... 10124356 10124846 10125537] [280.         292.5        296.92307692 ... 681.53846154 681.66666667
#  705.45454545]
# /home/lukeai/Documents/pytorch-a2c-ppo-acktr-gail/baselines/bench/monitor.py:161: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
def default_xy_fn(r):
    x = np.cumsum(r.monitor.l)
    y = smooth(r.monitor.r, radius=10)
    return x,y

for result in results:
    x, y = default_xy_fn(result)
    x, y = map(np.asarray, (x, y))

with open('test.csv', 'w', newline='') as csvfile:
    fieldnames = ['steps','mean rewards'] 
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    
    for steps,reward in zip(x,y):
        writer.writerow({'steps': steps, 'mean rewards': reward})
